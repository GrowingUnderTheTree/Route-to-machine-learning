# %% [markdown]
# <a href="https://colab.research.google.com/github/GrowingUnderTheTree/Route-to-machine-learning/blob/main/line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as df
import numpy as np

# %%
df = df.read_csv('AAPL.csv')
y = df['newclose']
y1 = df['newopen']

# %%
plt.plot(y)
plt.plot(y1, color='r', linestyle="dotted")
plt.show
# Out:
# <function matplotlib.pyplot.show>
