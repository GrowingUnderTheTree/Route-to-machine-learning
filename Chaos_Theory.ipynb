# %% [markdown]
# <a href="https://colab.research.google.com/github/GrowingUnderTheTree/Route-to-machine-learning/blob/main/Chaos_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ![image_2022-03-03_135559.png](data:image/png;base64,...)

# %%
num = random.random() + 3
num2 = random.randint(12,28) + num
num3 = random.random() + random.random() + 4
print(num)
print(num2)
print(num3)
def lorenz(x,y,z,s=num3,r=num2,b=num):
  dotx = s*(y-x)
  doty = r*x - y - x*z
  dotz = x*y - b*z
  return dotx,doty,dotz
# Out:
# 3.4122204453254543
# 25.412220445325453
# 4.3998703764463105

# %%
dt = 0.01
numstep = 10000

# %%
xs = np.empty(numstep + 1)
ys = np.empty(numstep + 1)
zs = np.empty(numstep + 1)
xs[0],ys[0],zs[0] = (0.,1.,1.05)

# %%
for i in range(numstep):
  dotx,doty,dotz = lorenz(xs[i],ys[i],zs[i])
  xs[i + 1] = xs[i] + (dotx * dt)
  ys[i + 1] = ys[i] + (doty * dt)
  zs[i + 1] = zs[i] + (dotz * dt)

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot(xs, ys, zs, lw=0.5)
plt.show()

# %%
# Out:
# 0.19982898730464815
